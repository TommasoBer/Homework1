# %%
# collections.Counter()

from collections import Counter
tot_scarpe = int(input())
taglie_scarpe = list(map(int,input().split()))
taglie_paia = Counter(taglie_scarpe)
guadagno = 0
if tot_scarpe != len(taglie_scarpe):
    print("C'è un errore")
else:
    n_clienti = int(input())
    for i in range(0,n_clienti):
        taglia, prezzo = map(int,input().split())
        
        if taglia in taglie_paia.keys():
            if taglie_paia[taglia] == 0 :
                #print(taglie_paia[taglia])
                guadagno = guadagno + 0
                #print("baccala")
            else:
                #print(taglie_paia[taglia])
                x = taglie_paia[taglia]
                xa = x-1
                taglie_paia[taglia] = xa
                #print(taglie_paia[taglia])
                guadagno = guadagno + prezzo
        else:
            guadagno = guadagno + 0
        
    print(guadagno)

# %%
# DefaultDict Tutorial

from collections import defaultdict
n, m = map(int,input().split())
lista_a = defaultdict(list)
#lista_a = dict(lista_a)
lista_b = []
for i in range (0,n):
    x = str(input())
    lista_a[x].append(i+1)
for j in range(0,m):
    y = str(input())
    lista_b.append(y)
for word in lista_b:
    if word in lista_a.keys():
        #print(lista_a[word])
        u = lista_a[word]
        a = " ".join(str(n) for n in u)
        print(a)
    else:
        print("-1")

# %%
# Collections.namedtuple()

from collections import namedtuple
somma = 0
n_tot = int(input())
features_student = input().split()
studenti = namedtuple('studente',features_student)
for i in range(0, n_tot):
    fet1 , fet2, fet3, fet4 = map(str, input().split())
    studente = studenti(fet1,fet2,fet3,fet4)
    voto = studente.MARKS
    voto = int(voto)
    somma = somma + voto
print('{:.2f}'.format(somma/n_tot))

# %%
#Collections.OrderedDict()

from collections import OrderedDict
product_price = OrderedDict()
n_oggetti = int(input())
for i in range (0, n_oggetti):
    element = list(map(str, input().split())) 
    if len(element) == 2 :
        prodotto = element[0]
        prezzo = element [1]
        prezzo = int(prezzo)
        if prodotto in product_price.keys() :
            m = product_price[prodotto]
            m = int(m)
            prezzo = prezzo + m
            product_price[prodotto]=prezzo

        else:
            product_price[prodotto]=prezzo
            
    elif len(element) > 2 :
        prezzo = element[-1]
        prezzo = int(prezzo)
        prodotto = " ".join(element[:-1])
        if prodotto in product_price.keys() :
            m = product_price[prodotto]
            m = int(m)
            prezzo = prezzo + m
            product_price[prodotto]=prezzo

        else:
            product_price[prodotto]=prezzo
        
    
    
for x, y in product_price.items():
  print(x, y)

# %%
# Word Order

from collections import Counter
n_parole = int(input())
set1 = []
for i in range (0,n_parole):
    x = input()
    set1.append(x)
x = Counter(set1)
chiavi = x.keys()
print(len(chiavi))
val = x.values()
val = list(val)
value = [str(a) for a in val]
val = " ".join(value)
print(val)

# %%
# Collections.deque()

from collections import deque
n_operazioni = int(input())
d = deque()
for i in range(0, n_operazioni):
    comando_val = list(map(str, input().split()))
    if len(comando_val) == 1:
        comando = comando_val[0]
        if comando == "pop":
            
            d.pop()
        elif comando =="popleft":
            
            d.popleft()
    else:
        comando = comando_val[0]
        valore = comando_val[1]
        if comando == "append" :
                d.append(valore)
        elif comando == "appendleft":
                d.appendleft(valore)
d = list(d)
result = " ".join(d)
print(result)

# %%
# Piling Up!

from collections import deque
n_test = int(input())
for i in range(0,n_test):

    d2 = deque([2**32])
    n_cubi = int(input())
    d = deque(map(int,input().split()))
    for h in range (0, n_cubi):
        
        if d[0] == d[-1]:
            if d[0] <= d2[-1] :
                d2.append(d[0])
                d.popleft()
        elif d[0] > d[-1]:
            if d[0] <= d2[-1] :
                d2.append(d[0])
                d.popleft()
        elif d[0] < d[-1]:
            if d[-1] <= d2[-1] :
                
                d2.append(d[-1])
                d.pop()
                              
    if len(d) == 0 :
            print("Yes")
    else:
            print("No")

# %%
#Company Logo

import math
import os
import random
import re
import sys
from collections import Counter


if __name__ == '__main__':
    from collections import Counter
    s = input()
    nome_listato = list(s)
    #d_name = Counter(nome_listato)
    d_name = Counter(sorted(nome_listato)).most_common()
    del d_name[3:]
    d_name  = dict(d_name)
    #print(d_name)
    for x, y in d_name.items():
        print(x, y)
